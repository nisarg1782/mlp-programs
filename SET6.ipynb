# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/SET6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data.csv")
data
# Out:
#     Age  Height  Weight Gender                      Education    Income  \
# 0    35   160.0    70.0   Male                       Graduate   50000.0
# 1    30   155.0    65.0  Femal                   Postgraduate   40000.0
# 2    40   162.0    65.0   Male                  Undergraduate   35000.0
# 3    45   160.0    62.0   Male                    High School   70000.0
# 4    25   145.0    45.0  Femal  Vocational/Technical Training   25000.0
# 5    30   150.0    52.0  Femal             Associate's Degree  450000.0
# 6    42   152.0    58.0   Male        Some College, No Degree   65000.0
# 7    35   155.0    60.0   Male            High School Dropout   20000.0
# 8    30   148.0    48.0  Femal            Professional Degree   65000.0
# 9    28   146.0    54.0  Femal            Certificate Program   15000.0
# 10   35   160.0    70.0   Male                       Graduate   50000.0
# 11   30   155.0    65.0  Femal                   Postgraduate   40000.0
# ...

# %%
data.head()
# Out:
#    Age  Height  Weight Gender                      Education   Income   Region
# 0   35   160.0    70.0   Male                       Graduate  50000.0    North
# 1   30   155.0    65.0  Femal                   Postgraduate  40000.0    South
# 2   40   162.0    65.0   Male                  Undergraduate  35000.0     East
# 3   45   160.0    62.0   Male                    High School  70000.0     West
# 4   25   145.0    45.0  Femal  Vocational/Technical Training  25000.0  Central

# %%
data["Gender"].value_counts()
# Out:
# Femal    18
# Male     17
# Name: Gender, dtype: int64

# %%
data["Gender"].mode()
# Out:
# 0    Femal
# Name: Gender, dtype: object

# %%
data["Age"].sum()
# Out:
# 1363

# %%
female_data=data[data["Gender"]=="Femal"]
female_data.shape
# Out:
# (18, 7)

# %%
data.loc[data["Income"].idxmax()]
# Out:
# Age                          30
# Height                    150.0
# Weight                     52.0
# Gender                    Femal
# Education    Associate's Degree
# Income                 450000.0
# Region                  Midwest
# Name: 5, dtype: object

# %%
education_data=data.groupby("Education")

# %%
education_data["Age"].mean()
# Out:
# Education
# Associate's Degree               30.0
# Certificate Program              28.0
# Graduate                         35.0
# High School                      45.0
# High School Dropout              35.0
# Postgraduate                     30.0
# Professional Degree              30.0
# Some College, No Degree          42.0
# Undergraduate                    40.0
# Vocational/Technical Training    25.0
# Name: Age, dtype: float64

# %%
data
# Out:
#     Age  Height  Weight Gender                      Education    Income  \
# 0    35   160.0    70.0   Male                       Graduate   50000.0
# 1    30   155.0    65.0  Femal                   Postgraduate   40000.0
# 2    40   162.0    65.0   Male                  Undergraduate   35000.0
# 3    45   160.0    62.0   Male                    High School   70000.0
# 4    25   145.0    45.0  Femal  Vocational/Technical Training   25000.0
# 5    30   150.0    52.0  Femal             Associate's Degree  450000.0
# 6    42   152.0    58.0   Male        Some College, No Degree   65000.0
# 7    35   155.0    60.0   Male            High School Dropout   20000.0
# 8    30   148.0    48.0  Femal            Professional Degree   65000.0
# 9    28   146.0    54.0  Femal            Certificate Program   15000.0
# 10   35   160.0    70.0   Male                       Graduate   50000.0
# 11   30   155.0    65.0  Femal                   Postgraduate   40000.0
# ...

# %%
data["Age"].mean()
# Out:
# 33.24390243902439

# %%
x=data["Region"].value_counts()
x
# Out:
# Southeast    5
# Southwest    5
# Northwest    5
# North        4
# South        4
# East         4
# Central      4
# Northeast    4
# West         2
# Midwest      2
# Name: Region, dtype: int64

# %%
plt.pie(x,labels=x.index)
plt.title("Region Disribution")
plt.show()

# %%
data["Weight"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-633b759f067f> in <cell line: 1>()
# ----> 1 data["Weight"]
#
# NameError: name 'data' is not defined

# %%
plt.box(data["Weight"].dropna())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...

# %%
data["Weight"]
# Out:
# 0     70.0
# 1     65.0
# 2     65.0
# 3     62.0
# 4     45.0
# 5     52.0
# 6     58.0
# 7     60.0
# 8     48.0
# 9     54.0
# 10    70.0
# 11    65.0
# 12    65.0
# 13    62.0
# 14    45.0
# 15    52.0
# 16    58.0
# 17    60.0
# 18    48.0
# 19    54.0
# 20    45.0
# 21    52.0
# 22    58.0
# 23    60.0
# 24    48.0
# 25    54.0
# 26    70.0
# 27     NaN
# 28    65.0
# 29    60.0
# 30    48.0
# 31    54.0
# 32    45.0
# 33    52.0
# 34    58.0
# 35    60.0
# 36    48.0
# 37    54.0
# 38    70.0
# 39     NaN
# 40    65.0
# Name: Weight, dtype: float64

# %%
data
# Out:
#     Age  Height  Weight Gender                      Education    Income  \
# 0    35   160.0    70.0   Male                       Graduate   50000.0
# 1    30   155.0    65.0  Femal                   Postgraduate   40000.0
# 2    40   162.0    65.0   Male                  Undergraduate   35000.0
# 3    45   160.0    62.0   Male                    High School   70000.0
# 4    25   145.0    45.0  Femal  Vocational/Technical Training   25000.0
# 5    30   150.0    52.0  Femal             Associate's Degree  450000.0
# 6    42   152.0    58.0   Male        Some College, No Degree   65000.0
# 7    35   155.0    60.0   Male            High School Dropout   20000.0
# 8    30   148.0    48.0  Femal            Professional Degree   65000.0
# 9    28   146.0    54.0  Femal            Certificate Program   15000.0
# 10   35   160.0    70.0   Male                       Graduate   50000.0
# 11   30   155.0    65.0  Femal                   Postgraduate   40000.0
# ...

# %%
plt.boxplot([data["Weight"], data["Age"]])
plt.show()

# %%
plt.plot(data["Weight"])
plt.show()
