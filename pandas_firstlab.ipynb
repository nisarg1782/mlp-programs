# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/pandas_firstlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
x_data=pd.DataFrame([{"name":"nisarg","age":21},{"name":"ajay","age":25}])
print(x_data)
# Out:
#      name  age
# 0  nisarg   21
# 1    ajay   25

# %%
data=pd.read_csv('/content/temp_data.csv')
print(data)
# Out:
#      name  age
# 0  nisarg   20
# 1    ajay   25
# 2   divay   30

# %%
df1=data.describe()

# %%
df1
# Out:
#         age
# count   3.0
# mean   25.0
# std     5.0
# min    20.0
# 25%    22.5
# 50%    25.0
# 75%    27.5
# max    30.0

# %%
x_data['name']
# Out:
# 0    nisarg
# 1      ajay
# Name: name, dtype: object

# %%
x_data.head(2)
# Out:
#      name  age
# 0  nisarg   21
# 1    ajay   25
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
x_data.tail(1)
# Out:
#    name  age
# 1  ajay   25

# %%
data[['name','age']].head(1)
# Out:
#      name  age
# 0  nisarg   20

# %%
data.iloc[:]
# Out:
#      name  age
# 0  nisarg   20
# 1    ajay   25
# 2   divay   30

# %%
data
# Out:
#      name  age
# 0  nisarg   20
# 1    ajay   25
# 2   divay   30

# %%
data[::2]
# Out:
#      name  age
# 0  nisarg   20
# 2   divay   30

# %%
data['gender']=['m','m','m']

# %%
data
# Out:
#      name  age gender
# 0  nisarg   20      m
# 1    ajay   25      m
# 2   divay   30      m

# %%
data['gender'].value_counts()
# Out:
# m    3
# Name: gender, dtype: int64

# %%
data[data['age']>21]
# Out:
#     name  age gender
# 1   ajay   25      m
# 2  divay   30      m

# %%
data[ (data['age']>25) & (data['gender']=='m') ]
# Out:
#     name  age gender
# 2  divay   30      m
