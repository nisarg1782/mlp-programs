# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/pandas_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pokeymon_data=pd.read_csv('pokemon_data.csv')
pokeymon_data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokeymon_data.head(2)
# Display Only First Two Records
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
pokeymon_data.tail(2)
# Display only last 2 records
# Out:
#        #                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 798  720  HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721           Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 798      130     80           6       True
# 799       90     70           6       True

# %%
pokeymon_data.shape
# display the number of rows and columns
# Out:
# (800, 12)

# %%
pokeymon_data.info()
# display the information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pokeymon_data.describe()
# Provide the statistics of numeric fields
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokeymon_data[1:3]
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
pokeymon_data.max()
# display the max value of numeric fields
# Out:
# <ipython-input-12-7752dc400e99>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pokeymon_data.max()
# #                          721
# Name          Zygarde50% Forme
# Type 1                   Water
# HP                         255
# Attack                     190
# Defense                    230
# Sp. Atk                    194
# Sp. Def                    230
# Speed                      180
# Generation                   6
# Legendary                 True
# dtype: object

# %%
pokeymon_data.columns
# Display all the columns name
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokeymon_data.Name
# Display the specific column
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokeymon_data[['Name','HP']]
# Display more than one columns at time
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
pokeymon_data['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokeymon_data[50:76]
# Display Record from 50 to 75
# Out:
#      #                   Name    Type 1    Type 2  HP  Attack  Defense  \
# 50  45              Vileplume     Grass    Poison  75      80       85
# 51  46                  Paras       Bug     Grass  35      70       55
# 52  47               Parasect       Bug     Grass  60      95       80
# 53  48                Venonat       Bug    Poison  60      55       50
# 54  49               Venomoth       Bug    Poison  70      65       60
# 55  50                Diglett    Ground       NaN  10      55       25
# 56  51                Dugtrio    Ground       NaN  35      80       50
# 57  52                 Meowth    Normal       NaN  40      45       35
# 58  53                Persian    Normal       NaN  65      70       60
# 59  54                Psyduck     Water       NaN  50      52       48
# 60  55                Golduck     Water       NaN  80      82       78
# 61  56                 Mankey  Fighting       NaN  40      80       35
# ...

# %%
pokeymon_data.iloc[50:76,[1,4,5]]
# Display Record from 50 to 75
# Out:
#                      Name  HP  Attack
# 50              Vileplume  75      80
# 51                  Paras  35      70
# 52               Parasect  60      95
# 53                Venonat  60      55
# 54               Venomoth  70      65
# 55                Diglett  10      55
# 56                Dugtrio  35      80
# 57                 Meowth  40      45
# 58                Persian  65      70
# 59                Psyduck  50      52
# 60                Golduck  80      82
# 61                 Mankey  40      80
# 62               Primeape  65     105
# 63              Growlithe  55      70
# 64               Arcanine  90     110
# 65                Poliwag  40      50
# 66              Poliwhirl  65      65
# 67              Poliwrath  90      95
# 68                   Abra  25      20
# 69                Kadabra  40      35
# 70               Alakazam  55      50
# 71  AlakazamMega Alakazam  55      50
# 72                 Machop  70      80
# 73                Machoke  80     100
# ...

# %%
pokeymon_data[pokeymon_data['HP']>100]
# define the condition
# Out:
#        #              Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 44    39        Jigglypuff  Normal   Fairy  115      45       20       45
# 45    40        Wigglytuff  Normal   Fairy  140      70       45       85
# 96    89               Muk  Poison     NaN  105     105       75       65
# 120  112            Rhydon  Ground    Rock  105     130      120       45
# 121  113           Chansey  Normal     NaN  250       5        5       35
# ..   ...               ...     ...     ...  ...     ...      ...      ...
# 753  683        Aromatisse   Fairy     NaN  101      72       72       99
# 769  699           Aurorus    Rock     Ice  123      77       72       99
# 792  716           Xerneas   Fairy     NaN  126     131       95      131
# 793  717           Yveltal    Dark  Flying  126     131       95      131
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokeymon_data[(pokeymon_data['HP']>80) & (pokeymon_data['Attack']>50)]
# Out:
#        #                 Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 22    18              Pidgeot  Normal  Flying   83      80       75       70
# 23    18  PidgeotMega Pidgeot  Normal  Flying   83      80       80      135
# 36    31            Nidoqueen  Poison  Ground   90      92       87       75
# 39    34             Nidoking  Poison  Ground   81     102       77       85
# 41    36             Clefable   Fairy     NaN   95      70       73       95
# ..   ...                  ...     ...     ...  ...     ...      ...      ...
# 789  713              Avalugg     Ice     NaN   95     117      184       44
# 791  715              Noivern  Flying  Dragon   85      70       80       97
# 792  716              Xerneas   Fairy     NaN  126     131       95      131
# 793  717              Yveltal    Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Groupby_data1=pokeymon_data.groupby('Name')
# Groupby_data1
# name_counts = Groupby_data1.size()
# print(name_counts)
Groupby_data1 = pokeymon_data.groupby('Name')

for name, group in Groupby_data1:
    print(name)
    print(group)
    print()
# Out:
# Abomasnow
#
# AbomasnowMega Abomasnow
#
# Abra
#
# Absol
#
# AbsolMega Absol
#
# Accelgor
#
# AegislashBlade Forme
#
# AegislashShield Forme
#
# Aerodactyl
#
# AerodactylMega Aerodactyl
#
# Aggron
#
# AggronMega Aggron
#
# Aipom
#
# Alakazam
#
# AlakazamMega Alakazam
#
# Alomomola
#
# Altaria
#
# AltariaMega Altaria
#
# Amaura
#
# Ambipom
#
# Amoonguss
#
# Ampharos
#
# AmpharosMega Ampharos
#
# Anorith
#
# Arbok
#
# Arcanine
#
# Arceus
#
# Archen
#
# Archeops
#
# Ariados
#
# Armaldo
#
# Aromatisse
#
# Aron
#
# Articuno
#
# Audino
#
# AudinoMega Audino
#
# Aurorus
#
# Avalugg
#
# Axew
#
# Azelf
#
# Azumarill
#
# Azurill
#
# Bagon
#
# Baltoy
#
# Banette
#
# BanetteMega Banette
#
# Barbaracle
#
# Barboach
#
# Basculin
#
# Bastiodon
#
# Bayleef
#
# Beartic
#
# Beautifly
#
# Beedrill
#
# BeedrillMega Beedrill
#
# Beheeyem
#
# Beldum
#
# Bellossom
#
# Bellsprout
#
# Bergmite
#
# Bibarel
#
# Bidoof
#
# Binacle
#
# Bisharp
#
# Blastoise
#
# BlastoiseMega Blastoise
#
# Blaziken
#
# ...

# %%
pokeymon_data.drop_duplicates()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokeymon_data[pokeymon_data['Type 1']=="Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...
