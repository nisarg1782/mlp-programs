# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/student_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
student_data=pd.read_csv('student.csv')
student_data
# Out:
#     Enrollment_no      Name  Python  Java  Flutter
# 0         2023001    Nikita    85.0  77.0     12.0
# 1         2023002     Viraj    56.0  55.0     12.0
# 2         2023003     Ishan    84.0   NaN     45.0
# 3         2023004   parthiv    63.0   NaN     63.0
# 4         2023005  Riddhesh    85.0  55.0     33.0
# 5         2023006      Parv     NaN  41.0     55.0
# 6         2023007     Divay    85.0  41.0     11.0
# 7         2023008    Nisarg    75.0  22.0     22.0
# 8         2023009    karina    45.0  52.0     45.0
# 9         2023010    Sumeet    45.0  12.0     23.0
# 10        2023011   preksha    56.0  44.0     45.0
# 11        2023012     Rahul    38.0  88.0     75.0
# 12        2023013     Hetal     NaN  75.0     41.0
# 13        2023014    Jishan    66.0  84.0     12.0
# 14        2023015    Raghav    36.0  96.0      NaN
# 15        2023016    Prisha     NaN  78.0      NaN
# 16        2023017     shlok    32.0  45.0     47.0
# ...

# %%
student_data.head(5)
#display first five records
# Out:
#    Enrollment_no      Name  Python  Java  Flutter
# 0        2023001    Nikita    85.0  77.0     12.0
# 1        2023002     Viraj    56.0  55.0     12.0
# 2        2023003     Ishan    84.0   NaN     45.0
# 3        2023004   parthiv    63.0   NaN     63.0
# 4        2023005  Riddhesh    85.0  55.0     33.0

# %%
student_data.tail(7)
# display last seven records
# Out:
#     Enrollment_no     Name  Python  Java  Flutter
# 17        2023018    vivan    44.0   NaN      NaN
# 18        2023019  darshil    52.0  23.0     11.0
# 19        2023020    Nidhi    23.0  45.0     11.0
# 20        2023019  darshil    52.0  23.0     11.0
# 21        2023020    Nidhi    23.0  45.0     11.0
# 22        2023012    Rahul    38.0  88.0     75.0
# 23        2023013    Hetal     NaN  75.0     41.0

# %%
student_data['Java']
# Out:
# 0     77.0
# 1     55.0
# 2      NaN
# 3      NaN
# 4     55.0
# 5     41.0
# 6     41.0
# 7     22.0
# 8     52.0
# 9     12.0
# 10    44.0
# 11    88.0
# 12    75.0
# 13    84.0
# 14    96.0
# 15    78.0
# 16    45.0
# 17     NaN
# 18    23.0
# 19    45.0
# 20    23.0
# 21    45.0
# 22    88.0
# 23    75.0
# Name: Java, dtype: float64

# %%
student_data['Java'].max()
# Out:
# 96.0

# %%
java_marks=student_data['Java'].max()
java_student=student_data[student_data['Java' ]==java_marks]
java_student
# Out:
#     Enrollment_no    Name  Python  Java  Flutter
# 14        2023015  Raghav    36.0  96.0      NaN

# %%
python_marks=student_data['Python'].min()
python_marks
# Out:
# 23.0

# %%
python_student=student_data[student_data['Python']==python_marks]
python_student
# Out:
#     Enrollment_no   Name  Python  Java  Flutter
# 19        2023020  Nidhi    23.0  45.0     11.0
# 21        2023020  Nidhi    23.0  45.0     11.0

# %%
java_avg=student_data['Java'].mean()
java_avg
# Out:
# 55.42857142857143

# %%
student_data.describe()
# Out:
#        Enrollment_no     Python       Java    Flutter
# count   2.400000e+01  20.000000  21.000000  21.000000
# mean    2.023011e+06  54.150000  55.428571  33.380952
# std     5.955755e+00  20.479194  24.816469  21.941915
# min     2.023001e+06  23.000000  12.000000  11.000000
# 25%     2.023007e+06  38.000000  41.000000  12.000000
# 50%     2.023012e+06  52.000000  52.000000  33.000000
# 75%     2.023016e+06  68.250000  77.000000  45.000000
# max     2.023020e+06  85.000000  96.000000  75.000000

# %%
python_avg=student_data['Python'].mean()
python_avg
# Out:
# 54.15

# %%
flutter_avg=student_data['Flutter'].mean()

# %%
flutter_avg
# Out:
# 33.38095238095238

# %%
total_marks=student_data['Java']+student_data['Python']+student_data['Flutter']
student_data['tottal_marks']=total_marks
student_data
# Out:
#     Enrollment_no      Name  Python  Java  Flutter  tottal_marks
# 0         2023001    Nikita    85.0  77.0     12.0         174.0
# 1         2023002     Viraj    56.0  55.0     12.0         123.0
# 2         2023003     Ishan    84.0   NaN     45.0           NaN
# 3         2023004   parthiv    63.0   NaN     63.0           NaN
# 4         2023005  Riddhesh    85.0  55.0     33.0         173.0
# 5         2023006      Parv     NaN  41.0     55.0           NaN
# 6         2023007     Divay    85.0  41.0     11.0         137.0
# 7         2023008    Nisarg    75.0  22.0     22.0         119.0
# 8         2023009    karina    45.0  52.0     45.0         142.0
# 9         2023010    Sumeet    45.0  12.0     23.0          80.0
# 10        2023011   preksha    56.0  44.0     45.0         145.0
# 11        2023012     Rahul    38.0  88.0     75.0         201.0
# 12        2023013     Hetal     NaN  75.0     41.0           NaN
# ...

# %%
student_data[['Name','tottal_marks']]
# Out:
#         Name  tottal_marks
# 0     Nikita         174.0
# 1      Viraj         123.0
# 2      Ishan           NaN
# 3    parthiv           NaN
# 4   Riddhesh         173.0
# 5       Parv           NaN
# 6      Divay         137.0
# 7     Nisarg         119.0
# 8     karina         142.0
# 9     Sumeet          80.0
# 10   preksha         145.0
# 11     Rahul         201.0
# 12     Hetal           NaN
# 13    Jishan         162.0
# 14    Raghav           NaN
# 15    Prisha           NaN
# 16     shlok         124.0
# 17     vivan           NaN
# 18   darshil          86.0
# 19     Nidhi          79.0
# 20   darshil          86.0
# 21     Nidhi          79.0
# 22     Rahul         201.0
# 23     Hetal           NaN

# %%
student_data['tottal_marks'].sort_values()
# Out:
# 19     79.0
# 21     79.0
# 9      80.0
# 18     86.0
# 20     86.0
# 7     119.0
# 1     123.0
# 16    124.0
# 6     137.0
# 8     142.0
# 10    145.0
# 13    162.0
# 4     173.0
# 0     174.0
# 11    201.0
# 22    201.0
# 2       NaN
# 3       NaN
# 5       NaN
# 12      NaN
# 14      NaN
# 15      NaN
# 17      NaN
# 23      NaN
# Name: tottal_marks, dtype: float64

# %%
student_data.isnull()
# Out:
#     Enrollment_no   Name  Python   Java  Flutter  tottal_marks
# 0           False  False   False  False    False         False
# 1           False  False   False  False    False         False
# 2           False  False   False   True    False          True
# 3           False  False   False   True    False          True
# 4           False  False   False  False    False         False
# 5           False  False    True  False    False          True
# 6           False  False   False  False    False         False
# 7           False  False   False  False    False         False
# 8           False  False   False  False    False         False
# 9           False  False   False  False    False         False
# 10          False  False   False  False    False         False
# 11          False  False   False  False    False         False
# 12          False  False    True  False    False          True
# 13          False  False   False  False    False         False
# ...

# %%
null_student=student_data[['Java','Python','Flutter']].isnull()

# %%
null_student
# Out:
#      Java  Python  Flutter
# 0   False   False    False
# 1   False   False    False
# 2    True   False    False
# 3    True   False    False
# 4   False   False    False
# 5   False    True    False
# 6   False   False    False
# 7   False   False    False
# 8   False   False    False
# 9   False   False    False
# 10  False   False    False
# 11  False   False    False
# 12  False    True    False
# 13  False   False    False
# 14  False   False     True
# 15  False    True     True
# 16  False   False    False
# 17   True   False     True
# 18  False   False    False
# 19  False   False    False
# 20  False   False    False
# 21  False   False    False
# 22  False   False    False
# 23  False    True    False

# %%
students_with_null_marks = student_data[student_data[['Java', 'Python', 'Flutter']].isnull().any(axis=1)]
students_with_null_marks
# Out:
#     Enrollment_no     Name  Python  Java  Flutter  tottal_marks
# 2         2023003    Ishan    84.0   NaN     45.0           NaN
# 3         2023004  parthiv    63.0   NaN     63.0           NaN
# 5         2023006     Parv     NaN  41.0     55.0           NaN
# 12        2023013    Hetal     NaN  75.0     41.0           NaN
# 14        2023015   Raghav    36.0  96.0      NaN           NaN
# 15        2023016   Prisha     NaN  78.0      NaN           NaN
# 17        2023018    vivan    44.0   NaN      NaN           NaN
# 23        2023013    Hetal     NaN  75.0     41.0           NaN

# %%
student_sum_null=student_data[student_data['tottal_marks']==""]
student_sum_null
# Out:
# Empty DataFrame
# Columns: [Enrollment_no, Name, Python, Java, Flutter, tottal_marks]
# Index: []

# %%
null_marks=student_data[student_data['tottal_marks'].isnull()]
null_marks
# Out:
#     Enrollment_no     Name  Python  Java  Flutter  tottal_marks
# 2         2023003    Ishan    84.0   NaN     45.0           NaN
# 3         2023004  parthiv    63.0   NaN     63.0           NaN
# 5         2023006     Parv     NaN  41.0     55.0           NaN
# 12        2023013    Hetal     NaN  75.0     41.0           NaN
# 14        2023015   Raghav    36.0  96.0      NaN           NaN
# 15        2023016   Prisha     NaN  78.0      NaN           NaN
# 17        2023018    vivan    44.0   NaN      NaN           NaN
# 23        2023013    Hetal     NaN  75.0     41.0           NaN
