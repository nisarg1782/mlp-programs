# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/car_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
car_data=pd.read_csv("car_sales.csv")
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_data.head()
# Out:
#          Date      Salesperson   Customer Name Car Make  Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan     Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan      F-150      2016
# 2  2023-04-29     Ashley Ramos    Sandra Moore     Ford      Civic      2016
# 3  2022-09-04   Patrick Harris    Johnny Scott     Ford     Altima      2013
# 4  2022-06-16       Eric Lopez   Vanessa Jones    Honda  Silverado      2022
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40
# 2       33340         0.114536            3818.63
# 3       41937         0.092191            3866.20
# 4       20256         0.113490            2298.85

# %%
car_data.tail()
# Out:
#           Date     Salesperson          Customer Name   Car Make  Car Model  \
# 94  2023-01-23   Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13     Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31     Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29    Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16  Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
#     Car Year  Sale Price  Commission Rate  Commission Earned
# 94      2020       25964         0.098219            2550.15
# 95      2016       10872         0.109547            1190.99
# 96      2018       17650         0.105740            1866.32
# 97      2013       25256         0.055621            1404.76
# 98      2014       31462         0.103951            3270.51

# %%
car_data.columns
# Out:
# Index(['Date', 'Salesperson', 'Customer Name', 'Car Make', 'Car Model',
#        'Car Year', 'Sale Price', 'Commission Rate', 'Commission Earned'],
#       dtype='object')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               99 non-null     object
#  1   Salesperson        99 non-null     object
#  2   Customer Name      99 non-null     object
#  3   Car Make           99 non-null     object
#  4   Car Model          99 non-null     object
#  5   Car Year           99 non-null     int64
#  6   Sale Price         99 non-null     int64
#  7   Commission Rate    99 non-null     float64
#  8   Commission Earned  99 non-null     float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 7.1+ KB

# %%
car_data.describe()
# Out:
#           Car Year    Sale Price  Commission Rate  Commission Earned
# count    99.000000     99.000000        99.000000          99.000000
# mean   2016.161616  28622.989899         0.104150        2984.722323
# std       3.616027  10867.683713         0.027091        1415.463346
# min    2010.000000  10313.000000         0.051853         804.140000
# 25%    2013.000000  18382.000000         0.084937        1920.225000
# 50%    2016.000000  28160.000000         0.102855        2720.130000
# 75%    2019.000000  36864.500000         0.124378        3807.860000
# max    2022.000000  48916.000000         0.149926        6678.720000

# %%
car_data.isnull()
# Out:
#      Date  Salesperson  Customer Name  Car Make  Car Model  Car Year  \
# 0   False        False          False     False      False     False
# 1   False        False          False     False      False     False
# 2   False        False          False     False      False     False
# 3   False        False          False     False      False     False
# 4   False        False          False     False      False     False
# ..    ...          ...            ...       ...        ...       ...
# 94  False        False          False     False      False     False
# 95  False        False          False     False      False     False
# 96  False        False          False     False      False     False
# 97  False        False          False     False      False     False
# 98  False        False          False     False      False     False
#
#     Sale Price  Commission Rate  Commission Earned
# 0        False            False              False
# ...

# %%
# check in all columns where the null values define
car_data.isnull().sum()
# Out:
# Date                 0
# Salesperson          0
# Customer Name        0
# Car Make             0
# Car Model            0
# Car Year             0
# Sale Price           0
# Commission Rate      0
# Commission Earned    0
# dtype: int64

# %%
car_data['price'] = car_data['Sale Price'].astype(str)
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_data['Car Make'].unique()
# Out:
# array(['Nissan', 'Ford', 'Honda', 'Toyota', 'Chevrolet'], dtype=object)

# %%
car_data.value_counts()
# Out:
# Date        Salesperson         Customer Name      Car Make   Car Model  Car Year  Sale Price  Commission Rate  Commission Earned  price
# 2022-05-10  Matthew Campos      Brandon Kim        Chevrolet  Silverado  2016      19018       0.067880         1290.93            19018    1
# 2023-02-11  David Gomez         Linda Conrad       Nissan     Altima     2019      46164       0.144674         6678.72            46164    1
# 2023-02-01  Walter Robinson     Jeffrey Gillespie  Honda      Civic      2020      19526       0.128315         2505.47            19526    1
#             Anna Johnson        Damon Baker        Chevrolet  Civic      2012      28865       0.124314         3588.31            28865    1
# 2023-01-29  Richard Richardson  Justin Gray        Toyota     Silverado  2022      48224       0.090592         4368.72            48224    1
# ...

# %%
car_data['Car Make'].value_counts()
# Out:
# Ford         23
# Chevrolet    22
# Nissan       20
# Honda        17
# Toyota       17
# Name: Car Make, dtype: int64

# %%
car_data['Car Model'].value_counts()
# Out:
# Altima       26
# Civic        24
# Corolla      20
# F-150        16
# Silverado    13
# Name: Car Model, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
car_make_counts=car_data['Car Model'].value_counts()
car_make_counts
# Out:
# Altima       26
# Civic        24
# Corolla      20
# F-150        16
# Silverado    13
# Name: Car Model, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(10,8))
ax.pie(car_make_counts,labels=car_make_counts.index,autopct='%1.1f%%',startangle=45)
ax.axis("equal")
plt.show()

# %%
car_models=car_data['Car Make'].value_counts()

# %%
car_models
# Out:
# Ford         23
# Chevrolet    22
# Nissan       20
# Honda        17
# Toyota       17
# Name: Car Make, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(8,8))
ax.pie(car_models,labels=car_models.index,startangle=90,autopct='%1.1f%%')
ax.set_title("car models")
plt.show()

# %%
car_year=car_data['Car Year'].value_counts()

# %%
car_year
# Out:
# 2016    13
# 2013    12
# 2022    12
# 2018     9
# 2015     9
# 2014     7
# 2012     7
# 2019     7
# 2021     6
# 2011     6
# 2017     4
# 2010     4
# 2020     3
# Name: Car Year, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.pie(car_year,labels=car_year.index,autopct='%1.2f%%',startangle=30)
plt.show()

# %%
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_data.loc[car_data['Commission Earned'].idxmax()]
# Out:
# Date                   2023-02-11
# Salesperson           David Gomez
# Customer Name        Linda Conrad
# Car Make                   Nissan
# Car Model                  Altima
# Car Year                     2019
# Sale Price                  46164
# Commission Rate          0.144674
# Commission Earned         6678.72
# price                       46164
# Name: 55, dtype: object

# %%
car_data[['Car Make','Car Model']]
# Out:
#      Car Make  Car Model
# 0      Nissan     Altima
# 1      Nissan      F-150
# 2        Ford      Civic
# 3        Ford     Altima
# 4       Honda  Silverado
# ..        ...        ...
# 94       Ford     Altima
# 95     Nissan      F-150
# 96     Toyota  Silverado
# 97       Ford      Civic
# 98  Chevrolet     Altima
#
# [99 rows x 2 columns]

# %%
car_data.loc[car_data['Commission Earned'].idxmax()]
# Out:
# Date                   2023-02-11
# Salesperson           David Gomez
# Customer Name        Linda Conrad
# Car Make                   Nissan
# Car Model                  Altima
# Car Year                     2019
# Sale Price                  46164
# Commission Rate          0.144674
# Commission Earned         6678.72
# price                       46164
# Name: 55, dtype: object

# %%
car_max=car_data.loc[car_data['Commission Earned'].idxmin()]
car_max['Customer Name']
# Out:
# 'Kelly Beasley'

# %%
car_group=car_data.groupby('Customer Name')

# %%
car_group

# %%
# Assuming car_group is your grouped DataFrame

group_2022 = car_group.get_group('Mary Butler')
print(group_2022)
# Out:
#          Date      Salesperson Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD   Mary Butler   Nissan    Altima      2018
#
#    Sale Price  Commission Rate  Commission Earned  price
# 0       15983         0.070495            1126.73  15983

# %%
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
sales_data=car_data['Salesperson'].value_counts()
fig,ax=plt.subplots(figsize=(10,10))
ax.pie(sales_data,labels=sales_data.index,startangle=45,autopct='%1.1f%%')
plt.show()

# %%
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_data['Car Make'].value_counts().idxmax()
# Out:
# 'Ford'

# %%
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_sales=car_data.groupby('Car Year')['Sale Price'].sum()
car_sales
# Out:
# Car Year
# 2010    142580
# 2011    150129
# 2012    210482
# 2013    295947
# 2014    201012
# 2015    304547
# 2016    423997
# 2017    113807
# 2018    209907
# 2019    206686
# 2020     75674
# 2021    145032
# 2022    353876
# Name: Sale Price, dtype: int64

# %%
car_sales.to_csv('carsales.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-35d2b27693db> in <cell line: 2>()
#       1 car_sales.to_csv('carsales.csv')
# ----> 2 emp_data
#
# NameError: name 'emp_data' is not defined

# %%
plt.scatter(car_data['Car Make'],[''])
