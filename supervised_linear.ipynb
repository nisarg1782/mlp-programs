# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/supervised_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("housing.csv")
data
# Out:
#      Sq_Ft  Bedrooms  Bathrooms  Age          Price
# 0     3232         3          2   27  682777.150273
# 1     3107         4          3   14  712702.672025
# 2     2153         1          2   32  442952.288185
# 3     3764         3          3   22  766553.098528
# 4     1533         5          3   34  475021.303311
# ..     ...       ...        ...  ...            ...
# 995   2954         4          2   25  639568.713751
# 996   3225         3          2    3  676448.647926
# 997   1042         3          1   11  343628.053354
# 998   2299         2          2   35  482083.089811
# 999    739         3          3   25  311502.169738
#
# [1000 rows x 5 columns]

# %%
data.head()
# Out:
#    Sq_Ft  Bedrooms  Bathrooms  Age          Price
# 0   3232         3          2   27  682777.150273
# 1   3107         4          3   14  712702.672025
# 2   2153         1          2   32  442952.288185
# 3   3764         3          3   22  766553.098528
# 4   1533         5          3   34  475021.303311

# %%
x_data=data.drop("Price",axis=1)
x_data
# Out:
#      Sq_Ft  Bedrooms  Bathrooms  Age
# 0     3232         3          2   27
# 1     3107         4          3   14
# 2     2153         1          2   32
# 3     3764         3          3   22
# 4     1533         5          3   34
# ..     ...       ...        ...  ...
# 995   2954         4          2   25
# 996   3225         3          2    3
# 997   1042         3          1   11
# 998   2299         2          2   35
# 999    739         3          3   25
#
# [1000 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x_data,data["Price"],test_size=0.2)

# %%
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.predict(x_test)
# Out:
# array([427951.57358259, 655664.32607315, 300274.02946722, 642358.85560545,
#        216367.39242434, 396351.28536814, 585458.18698031, 301132.79559753,
#        848632.7909955 , 516913.1799634 , 329511.64915193, 440423.44569613,
#        920448.72064137, 653014.94496392, 845933.31783149, 786687.91113878,
#        507756.19481538, 658584.08084136, 385078.16437533, 419739.63451455,
#        493272.42628717, 798599.76015524, 510799.33378666, 413463.51237533,
#        667569.56815268, 438189.84689866, 390153.59563966, 926829.21321691,
#        261699.03189416, 515229.1943692 , 599519.91447236, 815853.00892461,
#        379614.90427569, 369978.48267473, 556411.42711158, 717125.10229417,
#        580783.46872749, 431616.55475297, 480378.99235619, 566152.30534899,
#        705713.5463129 , 324530.8195457 , 814747.74877634, 830969.46395842,
#        837282.61192724, 303765.91348295, 825622.28469984, 424941.65935639,
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test=np.sort(y_test)

# %%
y_pred=linear_model.predict(x_test)

# %%
y_pred=np.sort(y_pred)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e5b86ff07486> in <cell line: 1>()
# ----> 1 confusion_matrix(y_test,y_pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     315     (0, 2, 1, 1)
#     316     """
# --> 317     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     318     if y_type not in ("binary", "multiclass"):
#     319         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#     104     # No metrics support "multiclass-multioutput" format
#     105     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 106         raise ValueError("{0} is not supported".format(y_type))
#     107
# ...

# %%
linear_model.score(x_test,y_test)
# Out:
# -0.9807162572396488
