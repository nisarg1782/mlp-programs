# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg1782/mlp-programs/blob/main/pandas_matplot_uni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
car_data=pd.read_csv("car_sales.csv")
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_data.head(5)
# Out:
#          Date      Salesperson   Customer Name Car Make  Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan     Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan      F-150      2016
# 2  2023-04-29     Ashley Ramos    Sandra Moore     Ford      Civic      2016
# 3  2022-09-04   Patrick Harris    Johnny Scott     Ford     Altima      2013
# 4  2022-06-16       Eric Lopez   Vanessa Jones    Honda  Silverado      2022
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40
# 2       33340         0.114536            3818.63
# 3       41937         0.092191            3866.20
# 4       20256         0.113490            2298.85

# %%
car_data.tail(2)
# Out:
#           Date     Salesperson          Customer Name   Car Make Car Model  \
# 97  2022-12-29    Megan Kaiser  Christopher Alexander       Ford     Civic
# 98  2023-04-16  Michael Jordan     Thomas Blankenship  Chevrolet    Altima
#
#     Car Year  Sale Price  Commission Rate  Commission Earned
# 97      2013       25256         0.055621            1404.76
# 98      2014       31462         0.103951            3270.51

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               99 non-null     object
#  1   Salesperson        99 non-null     object
#  2   Customer Name      99 non-null     object
#  3   Car Make           99 non-null     object
#  4   Car Model          99 non-null     object
#  5   Car Year           99 non-null     int64
#  6   Sale Price         99 non-null     int64
#  7   Commission Rate    99 non-null     float64
#  8   Commission Earned  99 non-null     float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 7.1+ KB

# %%
car_data.describe()
# Out:
#           Car Year    Sale Price  Commission Rate  Commission Earned
# count    99.000000     99.000000        99.000000          99.000000
# mean   2016.161616  28622.989899         0.104150        2984.722323
# std       3.616027  10867.683713         0.027091        1415.463346
# min    2010.000000  10313.000000         0.051853         804.140000
# 25%    2013.000000  18382.000000         0.084937        1920.225000
# 50%    2016.000000  28160.000000         0.102855        2720.130000
# 75%    2019.000000  36864.500000         0.124378        3807.860000
# max    2022.000000  48916.000000         0.149926        6678.720000

# %%
car_data.value_counts()
# Out:
# Date        Salesperson         Customer Name      Car Make   Car Model  Car Year  Sale Price  Commission Rate  Commission Earned
# 2022-05-10  Matthew Campos      Brandon Kim        Chevrolet  Silverado  2016      19018       0.067880         1290.93              1
# 2023-02-11  David Gomez         Linda Conrad       Nissan     Altima     2019      46164       0.144674         6678.72              1
# 2023-02-01  Walter Robinson     Jeffrey Gillespie  Honda      Civic      2020      19526       0.128315         2505.47              1
#             Anna Johnson        Damon Baker        Chevrolet  Civic      2012      28865       0.124314         3588.31              1
# 2023-01-29  Richard Richardson  Justin Gray        Toyota     Silverado  2022      48224       0.090592         4368.72              1
#                                                                                                                                     ..
# ...

# %%
car_data.Date.head(2)
# Out:
# 0    2022-08-01
# 1    2023-03-15
# Name: Date, dtype: object

# %%
car_data["Car Make"].value_counts()
# Out:
# Car Make
# Ford         23
# Chevrolet    22
# Nissan       20
# Honda        17
# Toyota       17
# Name: count, dtype: int64

# %%
car_ford=car_data[car_data["Car Make"]=="Ford"]
car_ford
# Out:
#           Date         Salesperson          Customer Name Car Make  Car Model  \
# 2   2023-04-29        Ashley Ramos           Sandra Moore     Ford      Civic
# 3   2022-09-04      Patrick Harris           Johnny Scott     Ford     Altima
# 5   2022-12-18    Terry Perkins MD             John Olsen     Ford     Altima
# 7   2022-06-20       Norma Watkins           Michael Bond     Ford     Altima
# 8   2022-09-02        Scott Parker        Stephanie Smith     Ford    Corolla
# 9   2023-04-06        Andrew Smith      Ashley Moreno DDS     Ford      Civic
# 12  2022-05-29          Mia Acosta           Rebecca Best     Ford     Altima
# 19  2023-03-09   Patricia Reynolds          Alison Walker     Ford     Altima
# 20  2022-09-28   Michelle Gonzalez            Juan Davies     Ford    Corolla
# 30  2022-07-18      Brenda Morales             Jason Hahn     Ford     Altima
# 32  2022-09-05  Stephanie Trujillo          April Morales     Ford  Silverado
# ...

# %%
car_data.head(2)
# Out:
#          Date      Salesperson   Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan    Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan     F-150      2016
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40

# %%
car_condi=car_data[(car_data["Car Make"]=="Nissan") & (car_data["Car Year"]==2018)]

# %%
car_condi
# Out:
#           Date      Salesperson  Customer Name Car Make  Car Model  Car Year  \
# 0   2022-08-01  Monica Moore MD    Mary Butler   Nissan     Altima      2018
# 17  2022-08-23      Amy Solomon   Taylor Moore   Nissan  Silverado      2018
# 27  2022-07-14     Amber Cooper     Claire Day   Nissan      F-150      2018
# 37  2023-01-24    Julie Aguirre  Timothy Mccoy   Nissan  Silverado      2018
# 75  2023-02-19     Shawn Mullen   Jeremy Jones   Nissan      Civic      2018
#
#     Sale Price  Commission Rate  Commission Earned
# 0        15983         0.070495            1126.73
# 17       18482         0.086185            1592.88
# 27       30296         0.100170            3034.76
# 37       38307         0.079531            3046.60
# 75       16314         0.149344            2436.39

# %%
car_data.isnull().sum()
# Out:
# Date                 0
# Salesperson          0
# Customer Name        0
# Car Make             0
# Car Model            0
# Car Year             0
# Sale Price           0
# Commission Rate      0
# Commission Earned    0
# dtype: int64

# %%
car_data.head(1)
# Out:
#          Date      Salesperson Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD   Mary Butler   Nissan    Altima      2018
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73

# %%
car_data["Customer Name"].replace({"Mary Butler":"Nisarg"})
# Out:
# 0                    Nisarg
# 1            Richard Pierce
# 2              Sandra Moore
# 3              Johnny Scott
# 4             Vanessa Jones
#               ...
# 94             John Goodwin
# 95             James Turner
# 96                Mary Wong
# 97    Christopher Alexander
# 98       Thomas Blankenship
# Name: Customer Name, Length: 99, dtype: object

# %%
car_data.head(2)
# Out:
#          Date      Salesperson   Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan    Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan     F-150      2016
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40

# %%
x=car_data["Car Model"].value_counts()

# %%
plt.pie(x,labels=x.index,autopct="%1.1f%%")
plt.show()

# %%
car_data.head(2)
# Out:
#          Date      Salesperson   Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan    Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan     F-150      2016
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40

# %%
y=car_data["Car Make"].value_counts()

# %%
plt.barh(y.index,y)
plt.show()

# %%
car_data.head(2)
# Out:
#          Date      Salesperson   Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan    Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan     F-150      2016
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40

# %%
car_data["Salesperson"].value_counts()
# Out:
# Salesperson
# Monica Moore MD       1
# Kimberly Rasmussen    1
# Hayley Day            1
# Charles Cruz          1
# Laura Huff            1
#                      ..
# Brenda Morales        1
# Jason Cabrera         1
# Paul Potter           1
# Amber Cooper          1
# Michael Jordan        1
# Name: count, Length: 99, dtype: int64

# %%
x=car_data["Car Year"].value_counts()

# %%
plt.pie(x,labels=x.index,autopct="%1.1f%%")
plt.show()

# %%
car_com_grp=car_data.groupby("Car Model")

# %%
x=car_com_grp["Commission Rate"].sum()
x
# Out:
# Car Model
# Altima       2.712066
# Civic        2.575227
# Corolla      1.934843
# F-150        1.785902
# Silverado    1.302853
# Name: Commission Rate, dtype: float64

# %%
plt.bar(x.index,x)
plt.show()

# %%
x=car_data[car_data["Sale Price"].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 72
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
max_data=car_data["Sale Price"].max()

# %%
x=car_data[car_data["Sale Price"]==max_data]

# %%
x
# Out:
#           Date Salesperson   Customer Name Car Make Car Model  Car Year  \
# 72  2023-04-12  Hayley Day  Anthony Glover    Honda     F-150      2015
#
#     Sale Price  Commission Rate  Commission Earned
# 72       48916         0.099834            4883.46

# %%
car_emp=car_data.groupby("Salesperson")["Commission Earned"].sum()

# %%
car_emp.head(40)
# Out:
# Salesperson
# Alyssa Boyd            1190.99
# Amanda Butler          1766.73
# Amber Cooper           3034.76
# Amy Solomon            1592.88
# Andrew Smith           2445.14
# Anna Johnson           3588.31
# Ashley Brown           5910.67
# Ashley English         5296.66
# Ashley Ramos           3818.63
# Becky Stafford         3076.20
# Betty Young            5090.71
# Brenda Morales         1609.32
# Brian Moran            1155.59
# Carl Miller            2097.58
# Carrie Gordon          3797.56
# Carrie Howard          1071.26
# Chad Davis             1565.09
# Charles Cruz           2709.04
# Christian Williams     5304.13
# Christina Avery        3141.92
# Christopher Oneill     1771.33
# Christopher Taylor     2143.72
# David Diaz             3565.70
# David Gomez            6678.72
# David Wood             2194.62
# Deanna Rodriguez       3913.77
# Deborah Whitney        6205.44
# Donald Guerra          2550.15
# Eric Lopez             2298.85
# ...

# %%
car_emp["Salesperson"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salesperson'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.pie(car_emp,labels=car_emp.index)
plt.show()

# %%
car_data
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
# @title Car Year

from matplotlib import pyplot as plt
car_data['Car Year'].plot(kind='hist', bins=20, title='Car Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.scatter(car_data["Car Model"],car_data["Car Year"])
plt.show()

# %%
car_data.head(2)
# Out:
#          Date      Salesperson   Customer Name Car Make Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan    Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan     F-150      2016
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40

# %%
plt.plot(car_data["Salesperson"],car_data["Commission Earned"])
plt.show()

# %%
car_date=car_data.groupby("Date")
x=car_date["Sale Price"].sum()
plt.plot(x.index,x)

# %%
carp=car_data.groupby("Car Model")["Sale Price"].sum()
plt.boxplot(carp)
plt.show()
